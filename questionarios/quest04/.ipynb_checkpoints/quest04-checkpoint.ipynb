# %% [markdown]
# ## SME0828 -  Introdução à Ciência de Dados
# ## Questionário 4: Seleção de Modelos e Regularização
#
# ### Lucas Corlete Alves de Melo  13676461
#
#
# 1. Considere a base BostonHousing. Compare o coeficiente $R2$ obtido através de regressão linear múltipla, Lasso e ridge regression. Para os métodos Lasso e ridge regression, faça um gráfico de $\alpha$ x $R²$ conforme feito no notebook em sala.
#
#
# 2. Determine as variáveis que mais influenciam o preço de imóveis em Boston usando Lasso.
#
#
# 3. Considere os dados gerados com o código a seguir. Usando regularização, ajuste o grau do polinômio que define o modelo mais adequado.

# %% [markdown]
#     import numpy as np
#     from matplotlib import pyplot as plt
#     np.random.seed(10)
#
#     #função para gerar os dados
#     def function(x):
#         y = x**4 + x**9
#
#         return y
#
#     #training set
#     N_train = 20
#     sigma = 0.2
#     x_train = np.linspace(0,1,N_train)
#     y_train = function(x_train) + np.random.normal(0,sigma,N_train)
#     x_train = x_train.reshape(len(x_train),1)
#
#     fig = plt.figure(figsize=(8,4))
#     plt.scatter(x_train,y_train,facecolor="blue",edgecolors="b",s=100,label="training data")
#
#     #test set
#     N_test = 20
#     x_test = np.linspace(0,1,N_test)
#     y_test = function(x_test) + np.random.normal(0,sigma,N_test)
#     x_test = x_test.reshape(len(x_test),1)
#
#     #Curva teorica
#     xt = np.linspace(0,1,100)
#     yt = function(xt)
#     plt.plot(xt,yt,'-r',label="Theoretical curve")
#     plt.legend(fontsize=15)
#     plt.show(True)

# %% [markdown]
# ## Exercise 1

# %%
# Data loading

import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
random.seed(42) # define the seed (important to reproduce the results)

data = pd.read_csv('data/BostonHousing.csv', header=(0))

data = data.dropna(axis='rows') #remove NaN
# data = data.drop(data.columns[[0]], axis=1) # remove the first column (if useless), in that case is not useless

# stores classes names
# classes = np.array(pd.unique(data[data.columns[-1]]), dtype=str)  

print("Attributes matrix: Number of observations (rows) and classes (columns):", data.shape)
attributes = list(data.columns)
data.head(10)
# Out:
# Attributes matrix: Number of observations (rows) and classes (columns): (506, 14)
#       crim    zn  indus  chas    nox     rm    age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         b  lstat  medv
# ...

# %%
# Check if 'data' is a NumPy array or not
print(type(data))

data = data.to_numpy() #convert data to numpy to make manipulation easier
print(type(data))  # Output requested: <class 'numpy.ndarray'>
row, col = data.shape
y = data[:,-1]
x = data[:,0:col-1]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %%
#Selecting train and test sets

from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
p = 0.3 # train set partition
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = p, random_state = 42)

# %% [markdown]
# ### Linear Regression Model:

# %%
from sklearn.linear_model import LinearRegression

# modelo de regressão linear múltipla
lm = LinearRegression()
lm.fit(x_train, y_train)

y_pred = lm.predict(x_test)

# %%
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
l = plt.plot(y_pred, y_test, 'bo')
plt.setp(l, markersize=10)
plt.setp(l, markerfacecolor='C0')

plt.ylabel("y", fontsize=15)
plt.xlabel("Prediction", fontsize=15)

# mostra os valores preditos e originais
xl = np.arange(min(y_test), 1.2*max(y_test),(max(y_test)-min(y_test))/10)
yl = xl
plt.plot(xl, yl, 'r--')

plt.show(True)

# %%
# Calculating R2 coeficient and error coeficient

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

print('Linear Regression Error:\n')

R2 = r2_score(y_test, y_pred)
print('R2:', R2)

RSME = mean_squared_error(y_test, y_pred)
print("RSME:", RSME)          # Calculate the test MSE
# Out:
# Linear Regression Error:
#
# R2: 0.7112260057484929
# RSME: 21.517444231177233

# %% [markdown]
# ### Ridge Regression Model:

# %%
# With Ridge function with \alpha=0, same as Regression Linear model:

from sklearn.linear_model import Ridge, RidgeCV
from sklearn.metrics import mean_squared_error

# ajusta o modelo ridge regression
ridge = Ridge(alpha = 0)
ridge.fit(x_train, y_train)             # Fit a ridge regression on the training data
y_pred = ridge.predict(x_test)           # Use this model to predict the test data

print('Ridge Regression Error(alpha=0):\n')

from sklearn.metrics import r2_score
R2 = r2_score(y_test, y_pred)
print('R2:', R2)

RSME = mean_squared_error(y_test, y_pred)
print("RSME:", RSME)          # Calculate the test MSE
# Out:
# Ridge Regression Error(alpha=0):
#
# R2: 0.7112260057484929
# RSME: 21.517444231177226

# %%
# With Ridge function with non zero \alpha:

from sklearn.linear_model import Ridge, RidgeCV
from sklearn.metrics import mean_squared_error

# ajusta o modelo ridge regression
alpha=50
ridge = Ridge(alpha = alpha)
ridge.fit(x_train, y_train)             # Fit a ridge regression on the training data
y_pred = ridge.predict(x_test)           # Use this model to predict the test data

print(f'Ridge Regression Error(alpha={alpha}):\n')

from sklearn.metrics import r2_score
R2 = r2_score(y_test, y_pred)
print('R2:', R2)

RSME = mean_squared_error(y_test, y_pred)
print("RSME:", RSME)          # Calculate the test MSE
# Out:
# Ridge Regression Error(alpha=50):
#
# R2: 0.6911290735296658
# RSME: 23.014928862219648

# %%
# In Ridge Regression model (alpha>0), lets analyse how R2 varies according to alpha 

vR2 = []
valpha = []
# variamos os valaores de alpha
for ialpha in np.arange(0,100,5):
    ridge2 = Ridge(alpha = ialpha)
    ridge2.fit(x_train, y_train)             # Fit a ridge regression on the training data
    y_pred = ridge2.predict(x_test)           # Use this model to predict the test data
    r2 = r2_score(y_test, y_pred)
    vR2.append(r2)
    valpha.append(ialpha)
plt.plot(valpha, vR2, '-ro')
plt.xlabel("alpha", fontsize=15)
plt.ylabel("R2", fontsize=15)
plt.grid(True)
plt.show(True)

# %% [markdown]
# In $R2$ x $\alpha$, we can see that $R2$ coeficient decreases as we increase $\alpha$. So, in this Ridge Regression model $\alpha=0$ is a better option, ans that means that a Linear Regression model works better for *BostonHousing* dataset

# %% [markdown]
# ### LASSO (least absolute shrinkage and selection operator) method:

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

alpha = 1
# notice that we need to normalize the attributes: normalize = True
lasso = Lasso(alpha=alpha, max_iter=10**5) # by a reason that I dunno, '1e5' floating
lasso.fit(x_train, y_train)             # Fit a lasso method on the training data
y_pred = lasso.predict(x_test)           # Use this model to predict the test data

print(f'LASSO Method Error (alpha={alpha}):\n')

RSME = mean_squared_error(y_test, y_pred)
print("RSME:", RSME)          # Calculate the test MSE

from sklearn.metrics import r2_score
R2 = r2_score(y_test, y_pred)
print('R2:', R2)
# Out:
# LASSO Method Error (alpha=1):
#
# RSME: 25.639502928043992
# R2: 0.6559060829154338

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_squared_error

alpha = 1.75
# notice that we need to normalize the attributes: normalize = True
lasso = Lasso(alpha=alpha, max_iter=10**5) # by a reason that I dunno, '1e5' floating
lasso.fit(x_train, y_train)             # Fit a lasso method on the training data
y_pred = lasso.predict(x_test)           # Use this model to predict the test data

print(f'LASSO Method Error (alpha={alpha}):\n')

RSME = mean_squared_error(y_test, y_pred)
print("RSME:", RSME)          # Calculate the test MSE

from sklearn.metrics import r2_score
R2 = r2_score(y_test, y_pred)
print('R2:', R2)
# Out:
# LASSO Method Error (alpha=1.75):
#
# RSME: 30.03305792499266
# R2: 0.5969425549145473

# %%
vlR2 = []
vlalpha = []
for lalpha in np.arange(0.01,2,0.1):
    lasso = Lasso(alpha = lalpha)
    lasso.fit(x_train, y_train)             # Fit a ridge regression on the training data
    y_pred = lasso.predict(x_test)           # Use this model to predict the test data
    r2 = r2_score(y_test, y_pred)
    vlR2.append(r2)
    vlalpha.append(lalpha)
plt.plot(vlalpha, vlR2, '-ro')
plt.xlabel("alpha", fontsize=15)
plt.ylabel("R2", fontsize=15)
plt.grid(True)
plt.show(True)

# %% [markdown]
# Therefore, we have the following table with the results to RMSE and $R2$ errors:
#
#
# |     | RMSE | $R2$ | $\alpha$ |
# |-----|---------|---------|---------|
# | Linear Regression |   21.517 |   0.711 |   - |
# | Ridge Regression |   21.517 |   0.711 |   0 |
# | Ridge Regression |   23.015|   0.691 |   50 |
# | LASSO |   25.640 |   0.656 |   1 |
# | LASSO |   30.033|   0.597 |   1.75 |

# %% [markdown]
# Based on the results, we can conclude that:
#
# - Multiple Linear Regression and Ridge Regression with $\alpha$ = 0 performed best in terms of R²;
# - Lasso Regression, for the tested values of $\alpha$, performed slightly worse;
# - The $\alpha$ $x$ $R²$ graph would be crucial for better understanding the behavior of Ridge and Lasso models and selecting the optimal value of $\alpha$.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# No método Lasso, podemos calcular os coeficientes de modo a selecionar os atributos mais importantes. Se algum atributo apresentar os respectivo coeficiente igual a zero, então esse atributo não contribui para a regressão.

# %%
# # Data loading (again...)

# data = pd.read_csv('data/BostonHousing.csv', header=(0))

# data = data.dropna(axis='rows') #remove NaN
# # data = data.drop(data.columns[[0]], axis=1) # remove the first column (if useless), in that case is not useless

# # stores classes names
# # classes = np.array(pd.unique(data[data.columns[-1]]), dtype=str)  

# print("Attributes matrix: Number of observations (rows) and classes (columns):", data.shape)
# attributes = list(data.columns)
# data.head(10)

# # Check if 'data' is a NumPy array or not
# print(type(data))

# data = data.to_numpy() #convert data to numpy to make manipulation easier
# print(type(data))  # Output requested: <class 'numpy.ndarray'>
# row, col = data.shape
# y = data[:,-1]
# x = data[:,0:col-1]

# #Selecting train and test sets

# from sklearn.model_selection import train_test_split
# # Split the data into training and testing sets
# p = 0.3 # train set partition
# x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = p, random_state = 42)

# %%
#To this cell run correctly, the firsts cells (or the cell below) in this notebook need to be runned or the ouput 
#will be 'array([0.])'

alpha = 0.2
lasso = Lasso(alpha = alpha)
lasso.fit(x_train, y_train)
print(f'Coefficients (alpha={alpha}):')
lasso.coef_
# Out:
# Coefficients (alpha=0.2):
# array([-0.12364251,  0.03900651, -0.        ,  0.        , -0.        ,
#         3.6243241 , -0.01413224, -1.07177532,  0.22646894, -0.01082075,
#        -0.75279792,  0.01258721, -0.63014111])

# %% [markdown]
# Understanding the Coefficients:
#
# - **Numerical Value**: The numerical value of the coefficient indicates the magnitude and direction of the impact of the variable on the target variable (house price in the case of BostonHousing).
# - **Positive Coefficient**: An increase of one unit in the predictor variable is associated with an increase in the house price, holding all other variables constant.
# - **Negative Coefficient**: An increase of one unit in the predictor variable is associated with a decrease in the house price.
# - **Zero Coefficient**: The variable was considered irrelevant by the model and does not contribute significantly to the prediction of the house price.
# - **Selected Variables**: Variables with non-zero coefficients are those that the Lasso model considered relevant to explain the variation in house prices. The remaining variables had their coefficients "penalized" and became zero.
#
# In other words, if (output) array[j] is non zero value, it means the variable in column j in dataframe is relevant.

# %% [markdown]
# ## Exercise 3

# %%
import numpy as np
from matplotlib import pyplot as plt
np.random.seed(10)

#generating data
def function(x):
    y = x**4 + x**9
    return y

#training set
N_train = 20
sigma = 0.2
x_train = np.linspace(0,1,N_train)
y_train = function(x_train) + np.random.normal(0,sigma,N_train)
x_train = x_train.reshape(len(x_train),1)

fig = plt.figure(figsize=(8,4))
plt.scatter(x_train,y_train,facecolor="blue",edgecolors="b",s=100,label="training data")

#test set
N_test = 20
x_test = np.linspace(0,1,N_test)
y_test = function(x_test) + np.random.normal(0,sigma,N_test)
x_test = x_test.reshape(len(x_test),1)

#Theoretical curve
xt = np.linspace(0,1,100)
yt = function(xt)
plt.plot(xt,yt,'-r',label="Theoretical curve")
plt.legend(fontsize=15)
plt.show(True)

# %% [markdown]
# The data we have access to are the blue dots. The curve in red is unknown, representing the model generating the data.
# Let's make the adjustment using a polynomial of degree M.
#
# $$
# f(x,\theta)=\theta_0+\theta_1x+\theta_2x²+\theta_3x³+...+\theta_Mx^M
# $$
#
# For $M=1$, that is, a linear fit:
# $$
# f(x,\theta)=\theta_0+\theta_1x
# $$

# %%
from sklearn import linear_model

# uses linear regression to fit the model
model = linear_model.LinearRegression()
model.fit(x_train, y_train)

# predicts the values of y from x
xplot=np.linspace(0,1,200)
xplot=xplot.reshape(len(xplot), 1)
Y_pred = model.predict(xplot)

# show the results
fig = plt.figure(figsize=(8, 4))
plt.plot(xplot, Y_pred, label='Prediction: M=1', color = 'red')
plt.scatter(x_train, y_train, facecolor="blue", edgecolor="b", s=100, 
            label="training data")
plt.legend(fontsize=15)
plt.show(True)

# %% [markdown]
# Notamos que, nesse caso, o ajuste é muito ruim, pois os dados foram gerados a partir de uma função não-linear. Esse fenômeno é chamado **underfitting** e ocorre quando o viíes (bias) é grande.
#
# Vamos fazer o ajuste usando um polinômio de grau M e ajustar seu valor.
#
# We note that, in this case, the fit is very poor, as the data were generated from a non-linear function. This phenomenon is called **underfitting** and occurs when the bias is large.
#
# Let's make the adjustment using a polynomial of degree M and adjust its value.

# %%
from sklearn.preprocessing import PolynomialFeatures
# Defines the attribute array
poly3 = PolynomialFeatures(degree=3)
X = poly3.fit_transform(x_train) 
# print('X^0             X^1          Xˆ2         Xˆ3')
print(X)
model = linear_model.LinearRegression()
model.fit(X,y_train)
# we graph the curve obtained from the prediction
Xplot=poly3.fit_transform(xplot)
# Out:
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [1.00000000e+00 5.26315789e-02 2.77008310e-03 1.45793847e-04]
#  [1.00000000e+00 1.05263158e-01 1.10803324e-02 1.16635078e-03]
#  [1.00000000e+00 1.57894737e-01 2.49307479e-02 3.93643388e-03]
#  [1.00000000e+00 2.10526316e-01 4.43213296e-02 9.33080624e-03]
#  [1.00000000e+00 2.63157895e-01 6.92520776e-02 1.82242309e-02]
#  [1.00000000e+00 3.15789474e-01 9.97229917e-02 3.14914711e-02]
#  [1.00000000e+00 3.68421053e-01 1.35734072e-01 5.00072897e-02]
#  [1.00000000e+00 4.21052632e-01 1.77285319e-01 7.46464499e-02]
#  [1.00000000e+00 4.73684211e-01 2.24376731e-01 1.06283715e-01]
#  [1.00000000e+00 5.26315789e-01 2.77008310e-01 1.45793847e-01]
#  [1.00000000e+00 5.78947368e-01 3.35180055e-01 1.94051611e-01]
#  [1.00000000e+00 6.31578947e-01 3.98891967e-01 2.51931768e-01]
#  [1.00000000e+00 6.84210526e-01 4.68144044e-01 3.20309083e-01]
#  [1.00000000e+00 7.36842105e-01 5.42936288e-01 4.00058318e-01]
# ...

# %%
Y_pred = model.predict(Xplot)
fig = plt.figure(figsize=(8, 4))
plt.plot(xplot, Y_pred, label='Prediction: M=3', color = 'red')
plt.scatter(x_train, y_train, facecolor="blue", edgecolor="b", s=100, 
            label="training data")
plt.legend(fontsize=15)
plt.show(True)

# %% [markdown]
# In this case, the fit better reproduces the trend observed in the data.
#
# Let's see what happens when increases M too much.

# %%
poly9 = PolynomialFeatures(degree=9)
X = poly9.fit_transform(x_train)
model = linear_model.LinearRegression()
model.fit(X,y_train)

Xplot=poly9.fit_transform(xplot)
Y_pred = model.predict(Xplot)
fig = plt.figure(figsize=(8, 4))
plt.plot(xplot, Y_pred, label='Prediction: M=9', color = 'red')
plt.scatter(x_train, y_train, facecolor="blue", edgecolor="b", s=100, 
            label="training data")
plt.legend(fontsize=15)
plt.show(True)

# %% [markdown]
# For a polynomial of degree M=9, the curve fits all points. In principle, this seems like the best fit. However, this is an indication that the model is overfitting, so that it can predict the training set perfectly. In other words, the model is memorizing the data. This is a typical case of overfitting.
#
# Note also that the values of the model coefficients are quite high, being another indication of overfitting. These coefficients can be reduced using regularization, but that will not be discussed in this notebook.

# %%
print("Coeficientes do modelo ajustado:", model.coef_)
# Out:
# Coeficientes do modelo ajustado: [ 0.00000000e+00 -7.30194590e+00  5.11670703e+01 -2.41919133e+02
#   1.34224357e+03 -5.67339392e+03  1.37291743e+04 -1.80971211e+04
#   1.21674066e+04 -3.26875013e+03]

# %% [markdown]
# Finally, I leave here a cell that constructs a polynomial of degree M so that it is easy to see how the corresponding degrees of the polynomial affect the construction of the curve.

# %%
from sklearn.preprocessing import PolynomialFeatures

M=4
polyM = PolynomialFeatures(degree=M)
X = polyM.fit_transform(x_train)
model = linear_model.LinearRegression()
model.fit(X,y_train)

Xplot=polyM.fit_transform(xplot)
Y_pred = model.predict(Xplot)
fig = plt.figure(figsize=(8, 4))
plt.plot(xplot, Y_pred, label=f'Prediction: M={M}', color = 'red')
plt.scatter(x_train, y_train, facecolor="blue", edgecolor="b", s=100, 
            label="training data")
plt.legend(fontsize=15)
plt.show(True)
